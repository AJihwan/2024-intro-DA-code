# %% [markdown]
# <a href="https://colab.research.google.com/github/AJihwan/2024-intro-DA-code/blob/main/1st_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 간단한 데이터 시각화
# - matplotlib 활용 데이터 시각화
# - 한글처리

# %%
import sys
sys.version
# Out:
# '3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]'

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
type(1), type(3.5)
# Out:
# (int, float)

# %%
type('py'), type((1, ))
# Out:
# (str, tuple)

# %%
type([]), type((1, ))
# Out:
# (list, tuple)

# %%
type({1:1, 2:4}), type({1,2,3})
# Out:
# (dict, set)

# %% [markdown]
# # 데이터 시각화 준비
# - 그림을 선명하게
# - 모듈 설치 Koreanize-matplotlib
#  - 참조 사이트
# - 필요 패기지 import

# %%
# 1. 그림을 선명하게
# %config lnlineBackend.figure_format = 'retina'

# %%
# 2. 모듈 설치 koreanize-matplotlib
# !pip install koreanize-matplotlib==0.1.1
# Out:
# Requirement already satisfied: koreanize-matplotlib==0.1.1 in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib==0.1.1) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib==0.1.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib==0.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib==0.1.1) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib==0.1.1) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib==0.1.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib==0.1.1) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib==0.1.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib==0.1.1) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib==0.1.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib==0.1.1) (1.16.0)

# %%
3+4,10-6,3*5,3/2,3//2
# Out:
# (7, 4, 15, 1.5, 1)

# %%
3**2, 10%3
# Out:
# (9, 1)

# %%
'py'+'thon'
# Out:
# 'python'

# %%
'py'*3
# Out:
# 'pypypy'

# %%
divmod(10,3)
# Out:
# (3, 1)

# %%
int('30')+float('3.56')
# Out:
# 33.56

# %%
abs(-10),bool(0)
# Out:
# (10, False)

# %%
chr(90),ord('a'),ord('A')
# Out:
# ('Z', 97, 65)

# %%
eval('3+4*5')
# Out:
# 23

# %%
s='py'
id(s)
# Out:
# 135034146234160

# %%
data=input('나이는?')
data=int(data)
data
# Out:
# 나이는?20
# 20

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.title('데이터 시각화의 한글 준비와 기본 직선 그래프')
plt.plot([10,5,20,30])
plt.show()

# %%
import pandas as pd

pop = pd.read_csv("202311_202311_주민등록인구및세대현황_월간.csv", encoding='cp949', index_col=0,thousands=',')
pop
# Out:
#                        2023년11월_총인구수  2023년11월_세대수  2023년11월_세대당 인구  \
# 행정구역
# 전국  (1000000000)            51337076      23904793             2.15
# 서울특별시  (1100000000)          9390925       4469374             2.10
# 부산광역시  (2600000000)          3295496       1564199             2.11
# 대구광역시  (2700000000)          2376044       1093499             2.17
# 인천광역시  (2800000000)          2993492       1347984             2.22
# 광주광역시  (2900000000)          1420822        655552             2.17
# 대전광역시  (3000000000)          1443106        680226             2.12
# 울산광역시  (3100000000)          1103752        490174             2.25
# 세종특별자치시  (3600000000)         386256        160764             2.40
# 경기도  (4100000000)           13628135       5974055             2.28
# 강원특별자치도  (5100000000)        1528635        760636             2.01
# 충청북도  (4300000000)           1594038        779978             2.04
# 충청남도  (4400000000)           2129591       1034508             2.06
# 전라북도  (4500000000)           1756183        861263             2.04
# 전라남도  (4600000000)           1804875        911302             1.98
# 경상북도  (4700000000)           2556262       1282673             1.99
# 경상남도  (4800000000)           3253619       1525337             2.13
# 제주특별자치도  (5000000000)         675845        313269             2.16
#
#                        2023년11월_남자 인구수  2023년11월_여자 인구수  2023년11월_남여 비율
# 행정구역
# 전국  (1000000000)              25572695         25764381            0.99
# 서울특별시  (1100000000)            4543055          4847870            0.94
# 부산광역시  (2600000000)            1606680          1688816            0.95
# 대구광역시  (2700000000)            1167480          1208564            0.97
# 인천광역시  (2800000000)            1497231          1496261            1.00
# 광주광역시  (2900000000)             701645           719177            0.98
# 대전광역시  (3000000000)             719805           723301            1.00
# 울산광역시  (3100000000)             567145           536607            1.06
# 세종특별자치시  (3600000000)           192396           193860            0.99
# 경기도  (4100000000)              6855041          6773094            1.01
# 강원특별자치도  (5100000000)           768910           759725            1.01
# 충청북도  (4300000000)              810734           783304            1.04
# 충청남도  (4400000000)             1091095          1038496            1.05
# 전라북도  (4500000000)              874078           882105            0.99
# 전라남도  (4600000000)              909744           895131            1.02
# 경상북도  (4700000000)             1291263          1264999            1.02
# 경상남도  (4800000000)             1638128          1615491            1.01
# 제주특별자치도  (5000000000)           338265           337580            1.00

# %%
pop.columns = ['총인구수','세대수','세대당인구','남자인구수','여자인구수','남여비율']
pop.head()
# Out:
#                          총인구수       세대수  세대당인구     남자인구수     여자인구수  남여비율
# 행정구역
# 전국  (1000000000)     51337076  23904793   2.15  25572695  25764381  0.99
# 서울특별시  (1100000000)   9390925   4469374   2.10   4543055   4847870  0.94
# 부산광역시  (2600000000)   3295496   1564199   2.11   1606680   1688816  0.95
# 대구광역시  (2700000000)   2376044   1093499   2.17   1167480   1208564  0.97
# 인천광역시  (2800000000)   2993492   1347984   2.22   1497231   1496261  1.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['총인구수'].plot(kind='hist', bins=20, title='총인구수')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['세대수'].plot(kind='hist', bins=20, title='세대수')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['세대당인구'].plot(kind='hist', bins=20, title='세대당인구')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['남자인구수'].plot(kind='hist', bins=20, title='남자인구수')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='총인구수', y='세대수', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='세대수', y='세대당인구', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='세대당인구', y='남자인구수', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='남자인구수', y='여자인구수', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['총인구수'].plot(kind='line', figsize=(8, 4), title='총인구수')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['세대수'].plot(kind='line', figsize=(8, 4), title='세대수')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['세대당인구'].plot(kind='line', figsize=(8, 4), title='세대당인구')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['남자인구수'].plot(kind='line', figsize=(8, 4), title='남자인구수')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
pop.index = [pop.index[i].split()[0] for i in range(len(pop))]
pop
# Out:
#              총인구수       세대수  세대당인구     남자인구수     여자인구수  남여비율
# 전국       51337076  23904793   2.15  25572695  25764381  0.99
# 서울특별시     9390925   4469374   2.10   4543055   4847870  0.94
# 부산광역시     3295496   1564199   2.11   1606680   1688816  0.95
# 대구광역시     2376044   1093499   2.17   1167480   1208564  0.97
# 인천광역시     2993492   1347984   2.22   1497231   1496261  1.00
# 광주광역시     1420822    655552   2.17    701645    719177  0.98
# 대전광역시     1443106    680226   2.12    719805    723301  1.00
# 울산광역시     1103752    490174   2.25    567145    536607  1.06
# 세종특별자치시    386256    160764   2.40    192396    193860  0.99
# 경기도      13628135   5974055   2.28   6855041   6773094  1.01
# 강원특별자치도   1528635    760636   2.01    768910    759725  1.01
# 충청북도      1594038    779978   2.04    810734    783304  1.04
# 충청남도      2129591   1034508   2.06   1091095   1038496  1.05
# 전라북도      1756183    861263   2.04    874078    882105  0.99
# 전라남도      1804875    911302   1.98    909744    895131  1.02
# 경상북도      2556262   1282673   1.99   1291263   1264999  1.02
# 경상남도      3253619   1525337   2.13   1638128   1615491  1.01
# 제주특별자치도    675845    313269   2.16    338265    337580  1.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# pop['총인구수'].plot(kind='hist', bins=20, title='총인구수')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# pop['세대수'].plot(kind='hist', bins=20, title='세대수')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# pop['세대당인구'].plot(kind='hist', bins=20, title='세대당인구')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# pop['남자인구수'].plot(kind='hist', bins=20, title='남자인구수')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# pop.plot(kind='scatter', x='총인구수', y='세대수', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# pop.plot(kind='scatter', x='세대수', y='세대당인구', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# pop.plot(kind='scatter', x='세대당인구', y='남자인구수', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# pop.plot(kind='scatter', x='남자인구수', y='여자인구수', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# pop['총인구수'].plot(kind='line', figsize=(8, 4), title='총인구수')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# pop['세대수'].plot(kind='line', figsize=(8, 4), title='세대수')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# pop['세대당인구'].plot(kind='line', figsize=(8, 4), title='세대당인구')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# pop['남자인구수'].plot(kind='line', figsize=(8, 4), title='남자인구수')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(pop['총인구수'])
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
pop1 = pop.sort_values('총인구수')
sns.barplot(x=pop1.index,y='총인구수',data=pop1)
plt.xticks(rotation=90)
plt.show()
